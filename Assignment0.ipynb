# %% [markdown]
# <a href="https://colab.research.google.com/github/AALAA117/Data_Analysis/blob/main/Assignment0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1: Introduction to Python and Colab

# %% [markdown]
# ## **Full name:** Aalaa Mohammed Galal
# ## **Institution:** University Of Cairo
# ## **Country:** Egypt

# %%
print("\"Hello, BRICS Astronomy\""
)
# Out:
# "Hello, BRICS Astronomy"
